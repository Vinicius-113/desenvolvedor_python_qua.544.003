# %% [markdown]
# # Título do meu documento
#
# nesta aula iremos aprender sobre como inserir ***markdowns*** dentro de arquivos do tipo **Jupyter Notebook**.
#
#
# >***Markdowns*** é um tipo de documento muito usado em ciência de  dados e também para alimentar Inteligência Artificial.
# >
# >Manipular este tipo de arquivo se torna fundamnetal para dominar as profissões do futuro que dependem de IAs.

# %% [markdown]
# ## Subtítulo de markdown
#
# o que diferencia um markdown de um notebook, é que no caso do notebook, ele também é capaz de ler codigos das linguagens de programação *R*, *Julia*, e é claro, *python*

# %% [markdown]
# ## Checklist
#
# ### Linguagens de programação aceitas em notebooks
#
# ✅Python<br>
# ✅Julia<br>
# ✅R
#
# ### Linguagens que iremos utilizar no curso
# ✅ Python<br>
# ❌Julia<br>
# ❌R
