# %% [markdown]
# # Aula do dia 04/09/2026
#
# hoje, iremos aprender a trabalhar com células python. AS células python executam código python dentro dos noteboks. Observe a célula python abaixo:

# %%
nome = "Marcos Vinicius"
texto = f"Esta é uma célula python escrita pelo melhor programador de todos os tempos: {nome} 🤷‍♂️"

print(texto)

# %% [markdown]
# A célula python também permite códigos de entrada de dados. Veja:

# %%
nome = input("Informe seu nome: ").strip().title()
print(nome)

# %% [markdown]
# AS células python são acumulativas, e reconhecem as variáveis das células anteriores.
#
# observe, por exemplo, a célula abaixo:

# %%
n1 = 5
print(f"O valor da variável 'n1' é {n1}.)

# %% [markdown]
# o valr de n1 é claramnete 5. porém, veja na próxima celula e diga qual será o valor da variável result:

# %%
result = 15 + n1
print(result)

# %% [markdown]
# o valor de result é 20, pois está somando 15 com n1, que tinha o valor de 5.
#
# mas agora observe a célula abaixo sem executá-la:

# %%
x = 10

# %% [markdown]
# Agora, faça o código abaixo na próxima célulla, execute e veja qual é o resultado:

# %%
result = 25 + x
print(result)
